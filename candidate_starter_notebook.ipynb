# %% [raw]
# # Data Science Intern Assessment
#
# **Candidate Name:** ________________
# **Date:** ________________
# **Duration:** 40 minutes
#
# ## Instructions
#
# 1. **Think Out Loud:** Please explain your thought process as you work
# 2. **Ask Questions:** Feel free to ask clarifying questions about the business context
# 3. **Focus on Process:** We're more interested in your approach than perfect results
# 4. **Time Management:** Keep an eye on the time and prioritize accordingly
#
# ## Dataset Information
#
# You'll be working with the **Telco Customer Churn Dataset**, which contains information about telecommunications customers and whether they canceled their service (churned).
#
# **Business Context:** The company wants to understand what factors lead to customer churn so they can develop retention strategies.
#
# ---

# %% [raw]
# ## Phase 1: Data Exploration & Understanding (15 minutes)
#
# ### Your Task:
# - Load and explore the dataset
# - Understand the structure and content
# - Identify potential data quality issues

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
import warnings
warnings.filterwarnings('ignore')

# Set style for better plots
plt.style.use('default')
sns.set_palette('husl')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 import matplotlib.pyplot as plt
#       5 import seaborn as sns
#       6 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# Load the dataset
# Option 1: If you have the real dataset
# df = pd.read_csv('datasets/telco_churn.csv')

# Option 2: Use the sample dataset for practice
df = pd.read_csv('datasets/sample_telco_data.csv')

print("Dataset loaded successfully!")
print(f"Shape: {df.shape}")

# %%
# TODO: Explore the dataset structure
# Hint: Use .head(), .info(), .describe()

# %% [raw]
# ## Phase 2: Data Analysis & Insights (15 minutes)
#
# ### Your Task:
# - Handle any data quality issues
# - Create meaningful visualizations
# - Extract key insights about customer churn

# %%
# TODO: Create 2-3 meaningful visualizations
# Suggested visualizations:
# 1. Churn distribution
# 2. Churn rate by contract type
# 3. Tenure vs Monthly charges (colored by churn)

plt.figure(figsize=(15, 5))

# Visualization 1
plt.subplot(1, 3, 1)
# Your code here

# Visualization 2
plt.subplot(1, 3, 2)
# Your code here

# Visualization 3
plt.subplot(1, 3, 3)
# Your code here

plt.tight_layout()
plt.show()

# %% [raw]
# ## Phase 3: Problem-Solving & Modeling Approach (10 minutes)
#
# ### Your Task:
# - Propose a modeling approach
# - Build a simple baseline model
# - Evaluate and discuss improvements

# %%
# TODO: Build a simple baseline model
# Hint: Start with logistic regression
